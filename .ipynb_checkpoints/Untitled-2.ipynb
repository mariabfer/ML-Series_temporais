# %% [markdown]
# ## **Perguntas do Geron**

# %% [markdown]
# ### How would you define Machine Learning?
#
# - "Machine Learning is the science (and art) of programming computers so they can
# learn from data."
#     - machine learning ensinar a maquina a partir de dados, com esses dados melhorar o seu desempenho.

# %% [markdown]
# ### Can you name four types of problems where it shines?
# - 1) "The examples that the system uses to learn are called the training set."
#     "spam filter is a Machine Learning program that can learn"
# - 2) "Another area where Machine Learning shines is for problems that either are too complex for traditional approaches or have no known algorithm."
#     - ele consegue se sair bem até quando se trata de problemas de algorotimos não conhecidos
# - 3) "Fluctuating environments: a Machine Learning system can adapt to new data"
#     - se adapita bem a mudança dos ambiente.
# - 4) "Getting insights about complex problems and large amounts of data"
#     - descobre padroes

# %% [markdown]
# ### What is a labeled training set?
# - é o conjunto de dados em que as intancias possuem um rotulo ou resposta correta.

# %% [markdown]
# ### What are the two most common supervised tasks?
# - as classificaçoes e as regressoes

# %% [markdown]
# ### Can you name four common unsupervised tasks?
# - são:
#     - Agrupamento.
#     - Redução de dimensionalidade.
#     - Detecção de anomalias.
#     - Aprendizado de regras de associação.

# %% [markdown]
# ### What type of Machine Learning algorithm would you use to allow a robot to walk in various unknown terrains?
#  - "Reinforcement Learning"
#     - aprendizado com reforço

# %% [markdown]
# ### What type of algorithm would you use to segment your customers into multiple groups?
# - K-Means

# %% [markdown]
# ### Would you frame the problem of spam detection as a supervised learning problem or an unsupervised learning problem?
# - "Supervised learning"
#     - por conta da trinamento ele ja passa a ve direto os rotulos .

# %% [markdown]
# ### What is an online learning system?
# - que vai recebendo dados continuamente

# %% [markdown]
# ### What is out-of-core learning?
# - É tecnica que é usada quando o dataset, dados, é muito grande se comparada a amemoria.

# %% [markdown]
# ### What type of learning algorithm relies on a similarity measure to make predictions?
# - "Instance-Based Learning"
#     - k-Nearest Neighbors
#     - Linear Regression
#     - Logistic Regression
#     - Support Vector Machines (SVMs)
#     - Decision Trees and Random Forests
#     - Neural networks

# %% [markdown]
# ### What is the difference between a model parameter and a learning algorithm’s hyperparameter?
# - 0 "model parameter" ele é com o aprendizado automaticamente durante o treinamento.
# - Já o "learning algorithm’s hyperparameter" é difinido antes do treinamento.

# %% [markdown]
# ### What do model-based learning algorithms search for? What is the most common strategy they use to succeed? How do they make predictions?
# -

# %% [markdown]
# ### Can you name four of the main challenges in Machine Learning?
# - Quantidade insuficiente de dados
# - Dados podem vim com baixa qualidade, tipo os ruidos.
# - Features irrelevantes.
# - Overfitting

# %% [markdown]
# ### If your model performs great on the training data but generalizes poorly to new instances, what is happening? Can you name three possible solutions?

# %% [markdown]
# ### What is a test set and why would you want to use it?

# %% [markdown]
# ### What is the purpose of a validation set?

# %% [markdown]
# ### What can go wrong if you tune hyperparameters using the test set?

# %% [markdown]
# ### What is repeated cross-validation and why would you prefer it to using a single validation set?
